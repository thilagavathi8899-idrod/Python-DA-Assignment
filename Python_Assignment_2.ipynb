# %%
age_list = [23,26,30,35,40]

# %%
print(age_list)
# Out:
# [23, 26, 30, 35, 40]

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]
print(name_list)
# Out:
# ['thilaga', 'sashtik', 'dhanvik', 'rithu', 'divya']

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]

name_list .append("yazhini")
print(name_list)
# Out:
# ['thilaga', 'sashtik', 'dhanvik', 'rithu', 'divya', 'yazhini']

# %%
age_list = [23,26,30,35,40]
age_list . insert(2,30)
print(age_list)
# Out:
# [23, 26, 30, 30, 35, 40]

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya","yazhini"]
name_list . remove("yazhini")
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
age_list = [23,26,30,30,35,40]
age_list . pop()
print(age_list)
# Out:
# [23, 26, 30, 30, 35]

# %%
age_list = [23,26,30,30,35,40]
age_list.extend([29,30,26])
print(age_list)
# Out:
# [23, 26, 30, 30, 35, 40, 29, 30, 26]

# %%
age_list = [23, 26, 30, 30, 35, 40, 29, 30, 26]
age_list.sort(reverse=True)
print(age_list)
# Out:
# [40, 35, 30, 30, 30, 29, 26, 26, 23]

# %%
age_list = [40, 35, 30, 30, 30, 29, 26, 26, 23]
max_age = max(age_list)
min_age = min(age_list)
total_age = sum(age_list)

print("Max age:", max_age)
print("Min age:", min_age)
print("Sum of ages:", total_age)
# Out:
# Max age: 40
# Min age: 23
# Sum of ages: 269

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]
print(name_list[0])
# Out:
# thilaga

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]
print(name_list[4])
# Out:
# divya

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]
print(name_list[2:5])
# Out:
# ['dhanvik', 'rithu', 'divya']

# %%
name_list = ["thilaga","sashtik","dhanvik","rithu","divya",]
print(name_list[::-1])
# Out:
# ['divya', 'rithu', 'dhanvik', 'sashtik', 'thilaga']

# %%
student_marks={'thilaga':80,
               'sashtik':100,
               'dhanvik':90,
               'rithu':60,'divya':70}
print(student_marks)
# Out:
# {'thilaga': 80, 'sashtik': 100, 'dhanvik': 90, 'rithu': 60, 'divya': 70}

# %%
student_marks={'thilaga':80,
               'sashtik':100,
               'dhanvik':90,
               'rithu':60,'divya':70}
print(student_marks['thilaga'])
# Out:
# 80

# %%
student_marks['janani']=80
print(student_marks)
# Out:
# {'thilaga': 80, 'sashtik': 100, 'dhanvik': 90, 'rithu': 60, 'divya': 70, 'janani': 80}

# %%
student_marks.update({'thilaga':82})
print(student_marks)
# Out:
# {'thilaga': 82, 'sashtik': 100, 'dhanvik': 90, 'rithu': 60, 'divya': 70, 'janani': 80}

# %%
student_marks={'thilaga':80,
               'sashtik':100,
               'dhanvik':90,
               'rithu':60,'divya':70,'janani':80}
print(student_marks.keys())
print(student_marks.values())
print(student_marks.items())
# Out:
# dict_keys(['thilaga', 'sashtik', 'dhanvik', 'rithu', 'divya', 'janani'])
# dict_values([80, 100, 90, 60, 70, 80])
# dict_items([('thilaga', 80), ('sashtik', 100), ('dhanvik', 90), ('rithu', 60), ('divya', 70), ('janani', 80)])

# %%
my_set = set(['a','e','i','o','u','a','a','i'])
print(my_set)
# Out:
# {'i', 'o', 'u', 'a', 'e'}

# %%
my_set = set(['a', 'e', 'i', 'o', 'u'])
# If you wanted to add 's' to the set, you would use my_set.add('s')
# my_set.add('s')
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_210/3985944023.py in <cell line: 0>()
#       1 my_set = set(['a,''e','i','o','u','a','a','i'])
# ----> 2 my_set[4]='s'
#       3 print(my_set)
#
# TypeError: 'set' object does not support item assignment

# %%
set1={1,3,5,7,9}
set2={2,3,5,8,10}
print("set1:",set1)
print("set2:",set2)
# Out:
# set1: {1, 3, 5, 7, 9}
# set2: {2, 3, 5, 8, 10}

# %%
#union
total_set = set1 | set2
print(total_set)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
#intersection
common_set = set1 & set2
print(common_set)
# Out:
# {3, 5}

# %%
score = int(input("enter the score(0 to 10):"))
if 0<= score <=10:
    print("valid score")
else:
    print("invaild score.score must be between 0 to 10.")
# Out:
# enter the score(0 to 10):7
# valid score

# %%
score = int(input("enter the score(o to 10):."))
if  score >7:
  print("Above Average:Excellent work!Keep maintaining your performance.")
elif 4<=score <=7:
  print("Average:Good effort! Keep practicing, there's room for improvement.")
else :
  print("Below Average:Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# enter the score(o to 10):.7
# Average:Good effort! Keep practicing, there's room for improvement.
