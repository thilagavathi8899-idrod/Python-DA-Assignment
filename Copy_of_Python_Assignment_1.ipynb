# %%
string = 'Hello'
T = input('Enter Your Name')
# Out:
# Enter Your NameThilaga

# %%
A = string + T
print(A)
# Out:
# HelloThilaga

# %%
B = (',Welcome To Python Progromming')
print (A + B)
# Out:
# HelloThilaga,Welcome To Python Progromming

# %%
Text = "HelloThilaga Welcome To Python Programming"

# %%
print (Text[0])
# Out:
# H

# %%
print (Text[41])
# Out:
# g

# %%
print (Text[5])
# Out:
# T

# %%
print (Text[11])
# Out:
# a

# %%
print ( Text[-1:-43:-1])
# Out:
# gnimmargorP nohtyP oT emocleW agalihTolleH

# %%
Word = Text[24:30]
print (Word)
# Out:
# Python

# %%
strM = "Python beginner tutorial"

# %%
upper_case = strM.upper()
print (upper_case)
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
lower_case = strM.lower()
print (lower_case)
# Out:
# python beginner tutorial

# %%
original_form = strM.capitalize()
print ("sentence after capitalize():",original_form)
# Out:
# sentence after capitalize(): Python beginner tutorial

# %%
count_t = strM.count('t')
print ("total occurrences of 't':",count_t)
# Out:
# total occurrences of 't': 3

# %%
M = strM.replace("Python","machine Learning")
print ("update string",M)
# Out:
# update string machine Learning beginner tutorial

# %%
t1 = (10,20,30)
t2 = (40,50,60)
t_combine = t1 + t2
print(t_combine)
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine[2])
# Out:
# 30

# %%
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[-3:])
# Out:
# (40, 50, 60)
